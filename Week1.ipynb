# %% [markdown]
# <a href="https://colab.research.google.com/github/Fahridanaa/PCVK_Ganjil_2024/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
# Nama: Fahridana Ahmad Rayyansyah
#
# Kelas: TI-3B
#
# Absen: 10
#
# ---
#
# # MODUL 1 - Penggunaan Github dan Google Colaboratory, Membaca dan Menampilkan Citra

# %% [markdown]
# ## Langkah (Step) 1
#
# Pada code awal, beberapa library yang akan digunakan adalah: **numpy**, **pandas**, **cv2**, **skimage**, **PIL**, **matplotlib**

# %%
# Import Library
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# ## Langkah (Step) 2
#
# baca Image dari URLs
#
# Pada langkah ini kita akan membaca image dari URLs, menampilkannya menggunakan OpenCV, perhatikan ada perbedaan ketika membuka image dalam RGB dan BGR. Channel Warna default untuk OpenCV adalah BGR.

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://wallpapers.com/images/high/field-minion-pfp-fat8az1zgbba2jwb.jpg"]

for url in urls:
  image = io.imread(url)                            #Read Image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)   #Resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    #Convert image to RGB
  final_frame = cv.hconcat((image,image_2))         #Concatenate image
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=900x253>

# %% [markdown]
# ## Langkah (Step) 3
#
# Melihat ukuran File Image

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  253  x  450
# <PIL.Image.Image image mode=RGB size=450x253>

# %% [markdown]
# ## Langkah (Step) 4
#
# Mengakses pixel dengan memberi garis diagonal menyilang

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat garis horizontal
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=900x253>

# %% [markdown]
# ## Pertanyaan
#
# **1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?**
#
# **Jawab:**
#
# > Google Colab memberikan environment yang lengkap untuk bahasa python sehingga tidak memerlukan konfigurasi dan installasi yang ribet, dan juga karena dijalankan di browser google colab sehingga lebih mudah untuk diakses dan digunakan
#
#
# **2.Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?**
#
# **Jawab:**
#
# > Library yang digunakan pada langkah ke 8 (langkah-1) adalah:
# * **Numpy** : library yang digunakan untuk memanipulasi array dan biasanya digunakan dalam linear aljabar, transformasi, dan kapabilitas angka acak.
# * **Pandas** : library yang digunakan untuk memanipulasi data dan juga digunakan sebagai analis data
# * **CV2** : library yang digunakan untuk mengerjakan komputer vision
# * **Skimage** : library yang mengsupport aplikasi proses gambar di python
# * **Matplotlib** : library yang menghasilkan angka dan menyediakan perangkat antarmuka pengguna grafis
#
# **3.Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :**
# ```
# image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
# ```
# **Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?**
#
# **Jawab:**
#
# > Kegunaannya adalah mengubah ukuran gambar menjadi setengahnya, hal tersebut dilakukan karena kita akan membandingkan 2 gambar (gambar dengan rgb dengan yg tidak) dalam 1 gambar, jika kode tersebut tidak dilakukan maka akan mendapatkan gambar dengan 2x ukuran gambar original
#
# **4.Perhatikan potongan kode progam berikut :**
#
# ```
# for y in range (lebar):
#   image_3[int((tinggi)/2),y] = [255,255,255]
# ```
#
# **Apakah kegunaan kode [255,255,255] ? Jelaskan!**
#
# **Jawab**
#
# > kode [255,255,255] adalah kode untuk warna putih, jadi kode tersebut akan mengubah sebuah pixel menjadi warna putih sesuai dengan kondisi perulangan
#
#
# **5.Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!**
#
#
# **Jawab**
#
# > semakin tinggi resolusi gambar maka semakin banyak pixel yang membuat gambar tersebut sehingga gambar tersebut akan terlihat mulus, sedangkan jika resolusi rendah maka pixel pada gambar tersebut juga sedikit sehingga akan menghasilkan gambar dengan kualitas buruk

# %% [markdown]
# ## Tugas
#
# 1. Lakukan langkah-langkah praktikum seperti diatas
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran

# %%
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range (tinggi):
  image_4[x,int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_4))
cv2_imshow(final_frame)
print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=900x253>

# %%
tinggi, lebar, _ = image.shape
image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for i in range(lebar):
    y = int((i * tinggi) / lebar)
    image_5[y, i] = [255, 255, 255]

for i in range(lebar):
    y = tinggi - 1 - int((i * tinggi) / lebar)
    image_5[y, i] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_5))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=900x253>

# %% [markdown]
# 3. Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang
# tertentu

# %%
image_6 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

length = 220
start = 80

for x in range (start, (start+length)):
  image_6[160, x] = [255,255,255]

final_frame = cv.hconcat((image_2, image_6))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=900x253>

# %% [markdown]
# 4. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam
# gambar

# %%
image_7 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

heigth, width, _ = image.shape
x = heigth // 2
y = width // 2;

lebar_kotak = 100
tinggi_kotak = 100

for i in range(x, min(x + tinggi_kotak, heigth)):
    for j in range(y, min(y + lebar_kotak, width)):
        image_7[i, j] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_7))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=900x253>
